# %% [markdown]
# # Config

# %%
#Libraries
import pandas as pd
import geopandas as gpd
import osmnx as ox
from config import PROCESSED_DATA_DIR

# %%
#Parameters
REGION = "Bizkaia, Spain"

# %% [markdown]
# # Load data

# %%
#Load data
bizkaia = ox.geocode_to_gdf(REGION)
bizkaia_gdf = gpd.GeoDataFrame(bizkaia, geometry='geometry', crs='EPSG:4326')

# %% [markdown]
# # Data management (Code)

# %%
bizkaia_gdf.head()
# Out:
#                                             geometry  bbox_west  bbox_south  \
# 0  MULTIPOLYGON (((-3.45091 43.23624, -3.45032 43...  -3.450912   42.968718
#
#    bbox_east  bbox_north   place_id  osm_type  osm_id        lat       lon  \
# 0   -2.41272    43.45686  268447968  relation  349034  43.238482 -2.851632
#
#       class            type  place_rank  importance addresstype    name  \
# 0  boundary  administrative          10    0.650805    province  Biscay
#
#                                         display_name
# 0  Biscay, Autonomous Community of the Basque Cou...

# %% [markdown]
# # Plots

# %%
# Plots and visualizations
bizkaia_gdf.plot()
# Out:
# <Axes: >

# %% [markdown]
# # Save results

# %%
#Save results and figures
bizkaia_gdf.to_file(PROCESSED_DATA_DIR/"bizkaia_boundary.gpkg")
