# %% [markdown]
# # Config

# %%
#Libraries

# %%
#Parameters

# %% [markdown]
# # Load data

# %%
#Load data

# %% [markdown]
# # Data management (Code)

# %% [markdown]
# # Plots

# %%
# Plots and visualizations

# %% [markdown]
# # Save results

# %%
#Save results and figures
